# %% [markdown]
# ##### PS : I started off with just .py not realizing I had to do this in jupyter so I am redoing this in my last 30mins of class hopefully it's okay. :) I still dont know how Jupyter works so here's my go.
# ## 1) Setup

# %%
import numpy as np
import pandas as pd

# Just wanted to see all the data without truncation
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## 2) Load Data

# %%
csv_path = "NSMES1988 - NSMES1988.csv"
df = pd.read_csv(csv_path)
print("Load shape:", df.shape)
df.head(10)
# Out:
# Load shape: (4406, 19)
#    Unnamed: 0  visits  nvisits  ovisits  novisits  emergency  hospital  \
# 0           1       5        0        0         0          0         1
# 1           2       1        0        2         0          2         0
# 2           3      13        0        0         0          3         3
# 3           4      16        0        5         0          1         1
# 4           5       3        0        0         0          0         0
# 5           6      17        0        0         0          0         0
# 6           7       9        0        0         0          0         0
# 7           8       3        0        0         0          0         0
# 8           9       1        0        0         0          0         0
# 9          10       0        0        0         0          0         0
#
#     health  chronic      adl   region  age  gender married  school  income  \
# 0  average        2   normal    other  6.9    male     yes       6  2.8810
# ...

# %% [markdown]
# ## 3) Overview
# I noticed there was numeber 0 as actually the row numbers and also age should be int and income should also be int....
#
# My initial Go for age was this "df.loc[df['age'] < 11, 'age'] = df['age'] * 10" which was working fine till I noticed age also was a single integer.

# %%
print(df.columns)
print(df.dtypes)
df.info()
df.describe()
df.describe(include='object')
# Out:
# Index(['Unnamed: 0', 'visits', 'nvisits', 'ovisits', 'novisits', 'emergency',
#        'hospital', 'health', 'chronic', 'adl', 'region', 'age', 'gender',
#        'married', 'school', 'income', 'employed', 'insurance', 'medicaid'],
#       dtype='object')
# Unnamed: 0      int64
# visits          int64
# nvisits         int64
# ovisits         int64
# novisits        int64
# emergency       int64
# hospital        int64
# health         object
# chronic         int64
# adl            object
# region         object
# age           float64
# gender         object
# married        object
# school          int64
# income        float64
# employed       object
# insurance      object
# medicaid       object
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4406 entries, 0 to 4405
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  4406 non-null   int64
# ...

# %% [markdown]
# ## 4) Missing Values

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0    0
# visits        0
# nvisits       0
# ovisits       0
# novisits      0
# emergency     0
# hospital      0
# health        0
# chronic       0
# adl           0
# region        0
# age           0
# gender        0
# married       0
# school        0
# income        0
# employed      0
# insurance     0
# medicaid      0
# dtype: int64

# %% [markdown]
# ## 5) Row 287 Concern
# If i convert all my ages to 10x then the 8 year old will be 80 I need to find a way to change my age to only everything after 10 is times 10.

# %%
display(df.iloc[[287]])
print("Age at row 287:", age_val)
# Out:
#      Unnamed: 0  visits  nvisits  ovisits  novisits  emergency  hospital  \
# 287         288       6        1        0         0          0         0
#
#       health  chronic      adl   region  age  gender married  school  income  \
# 287  average        2  limited  midwest  8.0  female      no       6   0.468
#
#     employed insurance medicaid
# 287       no       yes       no
# Age at row 287: 8.0

# %% [markdown]
# ## 5) Export JSON as NSMES1988.json
# Was I supposed to clean the file? Next time I will do better with this capstone assignments :(

# %%
df = pd.read_csv("NSMES1988 - NSMES1988.csv")
df.to_json("NSMES1988.json", orient="records", indent=4)
print("File exported as 'NSMES1988.json'")
# Out:
# File exported as 'NSMES1988.json'
